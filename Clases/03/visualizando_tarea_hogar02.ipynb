# %%
library("data.table") # cargo la libreria  data.table
library("rpart") # cargo la libreria  rpart
options(repr.plot.width = 25, repr.plot.height = 25)
if (!require("rpart.plot")) install.packages("rpart.plot")
require("rpart.plot")
# Out:
# Cargando paquete requerido: rpart.plot
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# "no hay paquete llamado 'rpart.plot'"
# Installing package into 'C:/Users/nacho/AppData/Local/R/win-library/4.4'
# (as 'lib' is unspecified)
# package 'rpart.plot' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\nacho\AppData\Local\Temp\RtmpIralZJ\downloaded_packages
# Cargando paquete requerido: rpart.plot

# %%
dataset <-fread("../02/gridsearch.csv")

modelo <- rpart(
    formula = "ganancia_mean ~ cp+maxdepth+minsplit+minbucket",
    data = dataset
)

# %%
rpart.plot::prp(modelo)
# Out:
# plot without title

# %%
dataset <-fread("../02/gridsearch_detalle.csv")

modelo <- rpart(
    formula = "ganancia_test ~ .",
    data = dataset
)

# %%
rpart.plot::prp(modelo)
# Out:
# plot without title
